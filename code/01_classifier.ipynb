# %% [markdown]
# ### Libraries

# %%
from helpers import *
import matplotlib.pyplot as plt
import cv2

# %%
image_dir_training = "../data/day_night/train/"
image_dir_test = "../data/day_night/test/"

# %% [markdown]
# ## Loading the data

# %%
image_list = load_images(image_dir_training)

# %% [markdown]
# ## Standarized list of input / outputs

# %%
standardize_list = standardize(image_list)

# %% [markdown]
# ## Visualize standardize

# %%
# Display a standardized image and its label

# Select an image by index
image_num = 0
selected_image = standardize_list[image_num][0]
selected_label = standardize_list[image_num][1]

# Display image and data about it
plt.imshow(selected_image)
print("Shape: "+str(selected_image.shape))
print("Label [1 = day, 0 = night]: " + str(selected_label))
# Out:
# Shape: (600, 600, 4)
# Label [1 = day, 0 = night]: 1

# %% [markdown]
# ## Feature extraction

# %%
# Convert and image to HSV colorspace
# Visualize the individual color channels

image_num = 3
train_im = standardize_list[image_num][0]

plot_image_channels(train_im)

# %% [markdown]
# ## Average brightness

# %%
avg, prediction = avg_brightness(train_im)
print("Avg brightness: " + str(avg))
print("the prediction is: ", prediction)
plt.imshow(train_im)
# Out:
# Avg brightness: 0.37170911458333333
# the prediction is:  0

# %% [markdown]
# ## Solution

# %%
test_image_list = load_images(image_dir_training)
test_standardize_list = standardize(image_list)

# %%
misclassified = get_misclassified_images(test_standardize_list)

get_accuracy(test_standardize_list, misclassified)
# Out:
# Accuracy: 1.0
# Number of misclassified images = 0out of6
